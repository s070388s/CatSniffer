# %% [markdown]
# # Command Over Serial – Minino BLE
#
# The **Minino BLE firmware** provides a serial interface for exploring Bluetooth Low Energy (BLE) devices through GATT operations such as discovery, reading, and writing.
#
# In this section of the notebook, you will:
# 1. Identify and select the USB serial port where your Minino is connected.
# 2. Establish a serial connection at the correct baud rate.
# 3. Send commands to the device and observe its responses.
#
# As a starting point, we’ll demonstrate the use of the command:
#
# gatt_cmdscan
#
# This command instructs Minino to begin scanning for nearby BLE devices and report their advertising information. Once confirmed, you can build on this workflow to issue additional GATT-related commands for deeper exploration.

# %%
# Automatically detect your USB serial port
import serial.tools.list_ports

def detect_serial_port():
    ports = serial.tools.list_ports.comports()
    for port in ports:
        if any(x in port.device for x in ["ttyUSB", "ttyACM", "cu.usbmodem", "usbserial", "COM"]):
            return port.device
    return None

selected_port = detect_serial_port()
if selected_port:
    print(f"Serial Port: {selected_port}")
else:
    print("No serial port detected.")
# Out:
# Serial Port: /dev/ttyACM0

# %%
# Detect the Minino Board
import serial, time

serial_port = selected_port if 'selected_port' in globals() else '/dev/cu.usbmodem2101'

serial_conn = None

is_a_minino_board = False

# Function to connect the Serial
def connect_serial():
    global serial_conn
    # Connect with the port
    try:
        serial_conn = serial.Serial(serial_port, 115200, timeout=1)
        time.sleep(2)
        return True
    except Exception as e:
        return False

# Function to send a command via Serial with a response 
def send_command_string_with_response(command:str):
    global serial_conn

    # Send any word to get the return
    if serial_conn and serial_conn.is_open:
        cmd = command+'\r\n'
        serial_conn.write(cmd.encode())
        time.sleep(0.3)
        try: 
            resp = serial_conn.read_all().decode(errors='ignore')
            return resp
        except:
            return 'Nan'
            
    else:
        return 'Nan'

# Function to send a command without response
def send_command_with_no_response(command:str):
    global serial_conn
    # Send any word to get the return
    if serial_conn and serial_conn.is_open:
        cmd = command+'\r\n'
        serial_conn.write(cmd.encode())

# Function to send a raw command 
def send_command(command):
    global serial_conn
    # Send any word to get the return
    if serial_conn and serial_conn.is_open:
        serial_conn.write(command)

# Function to disconnect Serial
def disconnect_serial():
    global serial_conn
    
    # Disconnect with the port
    if serial_conn and serial_conn.is_open:
        serial_conn.close()
        return True
    else: 
        return False

# Function to detect the minino
def detect_minino():
    connect_serial()
    data = send_command_string_with_response('h')
    if "minino" in data:
        is_a_minino_board = True
        print(f"Minino Detected at {serial_port}")
    else:
        print("Minino no detected")
    disconnect_serial()

# Test for minino
detect_minino()
# Out:
# Minino Detected at /dev/ttyACM0

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import threading

# Widgets Added on the UI
output_serial = widgets.Output()
command_input = widgets.Text(description='Comando:')
send_button = widgets.Button(description='Enviar')
close_button = widgets.Button(description='Cerrar Puerto', button_style='danger')
open_button = widgets.Button(description='Abrir Puerto', button_style='success')
auto_button = widgets.Button(description='▶️ Auto GATT Scan', button_style='info')

# Open Serial with button
def open_serial(b=None):
    if (connect_serial()):  
        with output_serial:
            clear_output()
            print(f"Connect at {serial_port}")
    else:
        with output_serial:
            clear_output()
            print("Not connected")

# Close serial with button
def close_serial(b=None):
    if (disconnect_serial()):
        with output_serial:
            clear_output()
            print(f"Device disconnect at {serial_port}")
    else:
        with output_serial:
            clear_output()
            print("Not device")


def send_command_label(b):
    cmd = command_input.value.strip()
    response = send_command_string_with_response(cmd)
    with output_serial:
            clear_output()
            print(f"{response}")

open_button.on_click(open_serial)
close_button.on_click(close_serial)
send_button.on_click(send_command_label)

# Display UI
display(widgets.HBox([open_button, close_button, auto_button]))
display(command_input, send_button, output_serial)
# Out:
# HBox(children=(Button(button_style='success', description='Abrir Puerto', style=ButtonStyle()), Button(button_…
# Text(value='', description='Comando:')
# Button(description='Enviar', style=ButtonStyle())
# Output()

# %%
# import ipywidgets as widgets
# from IPython.display import display, clear_output
# import threading

# output_serial = widgets.Output()
# command_input = widgets.Text(description='Comando:')
# send_button = widgets.Button(description='Enviar')
# close_button = widgets.Button(description='Cerrar Puerto', button_style='danger')
# open_button = widgets.Button(description='Abrir Puerto', button_style='success')
# auto_button = widgets.Button(description='▶️ Auto GATT Scan', button_style='info')

# def open_serial(b=None):
#     global serial_conn
#     try:
#         serial_conn = serial.Serial(serial_port, 115200, timeout=1)
#         time.sleep(2)
#         with output_serial:
#             clear_output()
#             print(f'✅ Puerto {serial_port} abierto a 115200 baudios.')
#     except Exception as e:
#         with output_serial:
#             clear_output()
#             print(f'❌ Error al abrir el puerto: {e}')

# def close_serial(b=None):
#     global serial_conn
#     if serial_conn and serial_conn.is_open:
#         serial_conn.close()
#         with output_serial:
#             print('🔌 Puerto cerrado correctamente.')

# def send_command(b):
#     global serial_conn
#     if serial_conn and serial_conn.is_open:
#         cmd = command_input.value.strip() + '\r\n'
#         serial_conn.write(cmd.encode())
#         time.sleep(0.3)
#         resp = serial_conn.read_all().decode(errors='ignore')
#         with output_serial:
#             print(f'📤 Enviado: {cmd.strip()}')
#             print(f'📥 Respuesta: {resp.strip()}')
#     else:
#         with output_serial:
#             print('⚠️ El puerto no está abierto.')

# def auto_gatt_scan(b=None):
#     def routine():
#         global serial_conn
#         if not serial_conn or not serial_conn.is_open:
#             open_serial()

#         time.sleep(1)
#         with output_serial:
#             print('📤 Enviando comando: gatt_cmdscan')
#         serial_conn.write(b'gattcmd_scan\r\n')

#         start_time = time.time()
#         duration = 120  # seconds (2 minutes)

#         try:
#             while time.time() - start_time < duration:
#                 if serial_conn.in_waiting:
#                     data = serial_conn.read(serial_conn.in_waiting).decode(errors='ignore')
#                     with output_serial:
#                         print(data.strip())
#                 time.sleep(1)
#         finally:
#             close_serial()

#     thread = threading.Thread(target=routine)
#     thread.start()

# # Button callbacks
# send_button.on_click(send_command)
# close_button.on_click(close_serial)
# open_button.on_click(open_serial)
# auto_button.on_click(auto_gatt_scan)

# # Display UI
# display(widgets.HBox([open_button, close_button, auto_button]))
# display(command_input, send_button, output_serial)
# Out:
# HBox(children=(Button(button_style='success', description='Abrir Puerto', style=ButtonStyle()), Button(button_…
# Text(value='', description='Comando:')
# Button(description='Enviar', style=ButtonStyle())
# Output()
# 📤 Enviando comando: gatt_cmdscan
# BEmjIUcYzrA=
# CRBSwD4ADgAAAKclwwwqXIAmBElLtA5FM/M=
# DRC1sz8AGQAAAMUlQBc9FBs85UcCARoCCgwK/0wAEAVCHJ2Msw==
# ERBH4z8AJQAAAMglYCPXwOdMzwECAQIZFvH8BKn4e23gz8VdNtl6EPIYi7DawCLlAA==
# EBDcFkAAJAAAALMlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# DRDMLEAAGQAAAMUlQBe2FDfuG0ECARoCCgwK/0wAEAVCHJ2Msw==
# ERDodEAAJwAAAKglAiX294djykACAQIM/3UAQh9AAAIPAPDxAAAAAAAAAAAAAAAAAAAA
# CRAhPkEADgAAANQlQwxe2xlMO32jIUcYzrA=
# EBBQRkEAIwAAAMYlQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
CU4XoEbPG0CAQIb/3UAAhhhsTqHAUVjT4+dNFcYo9QXAsXZrySO
# CRD4hnwADgAAANQlwwxe2xlMO304XoEbPG0=
# CxA/iHwAFAAAAMAlRBI4XoEbPG0L/3UApxujEr76tIs=
# CRD4pXwADgAAANQlQwxe2xlMO32jIUcYzrA=
# EBDN4XwAIwAAAMclQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
# DRAI/3wAGwAAAKklQBlHW9do2UMCARoCCggM/0wAEAc+H4+XkGlY
# ERAhBn0AJQAAAMglYCPXwOdMzwECAQIZFvH8BKn4e23gz8VdNtl6EPIYi7DawCLlAA==
# ERCCSn0AJwAAALYlYCWODwkEpHACAQIb/3UAAhhhsTLpARF7Pb+id20bHrbYnxQNcxO2
# EBBRvH0AJAAAALMlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# CRC+4n0ADgAAAKclwwwqXIAmBEm7CcaHBWU=
# DRA+UH4AGQAAAMclQBc9FBs85UcCARoCCgwK/0wAEAVCHJ2Msw==
# DRAd2X4AGQAAAMclQBe2FDfuG0ECARoCCgwK/0wAEAVCHJ2Msw==
# CRC72n4ADgAAANQlwwxe2xlMO322FDfuG0E=
# BxAC3H4ACAAAAMclRAa2FDfuG0E=
# EBAP4H4AJAAAAKclYCLMbJLHuQECAQIYFvH8BCBF
# YB2HF4mk3Vd1tHOMRCo4AW4Z
# EBDwqn8AIwAAAMclQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
# EBBEBoAAJAAAALIlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# DRDWGoAAGgAAAK4lIBgzRoBRtnARB7GRqykohWG1YElbLdMwOwk=
# ERCIZIAAJwAAAKklAiX294djykACAQIM/3UAQh9AAAIPAPDxAAAAAAAAAAAAAAAAAAAA
# ERBUt4AAJwAAAMAlYCU4XoEbPG0CAQIb/3UAAhhhsTqHAUVjT4+dNFcYo9QXAsXZrySO
# DRCSMYEAGwAAAKklQBlHW9do2UMCARoCCggM/0wAEAc+H4+XkGlY
# CRBBM4EADgAAANQlwwxe2xlMO31HW9do2UM=
# BxCHNIEACAAAAKklRAZHW9do2UM=
# ERDId4EAJQAAAMglYCPXwOdMzwECAQIZFvH8BKn4e23gz8VdNtl6EPIYi7DawCLlAA==
# ERDtgoEAJwAAALYlYCWODwkEpHACAQIb/3UAAhhhsTLpARF7Pb+id20bHrbYnxQNcxO2
# ChBYqYEAEAAAAKklQg5m53fdZvQH/0wAEgIAAw==
# EBCAbYIAJAAAALMlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# EBAxb4IAIwAAAMclQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
# DRD6eIIAGQAAAMclQBc9FBs85UcCARoCCgwK/0wAEAVCHJ2Msw==
# DRAS+IIAGQAAAMclQBe2FDfuG0ECARoCCgwK/0wAEAVCHJ2Msw==
# ERBRKIMAJwAAAMElQiWSfp15YxYeFvP+ShcjTTZPNhEyxHxAr2adMuM5H61X61llEYSS
# CRCLN4MADgAAAKglwwwqXIAmBElLtA5FM/M=
# EBBRPIMAJAAAAKwl
# mk3Vd1tHOMRCo4AW4Z
# EBDDHogAIwAAAMclQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
# ERAKOYkAJwAAAMAlYCU4XoEbPG0CAQIb/3UAAhhhsTqHAUVjT4+dNFcYo9QXAsXZrySO
# EBC0j4kAJAAAALMlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# DRCjlokAGwAAAKklQBlHW9do2UMCARoCCggM/0wAEAc+H4+XkGlY
# ERBU9YkAJwAAAKslAiX294djykACAQIM/3UAQh9AAAIPAPDxAAAAAAAAAAAAAAAAAAAA
# ERB8/okAJwAAALYlYCWODwkEpHACAQIb/3UAAhhhsTLpARF7Pb+id20bHrbYnxQNcxO2
# ERAnNIoAJQAAAMglYCPXwOdMzwECAQIZFvH8BKn4e23gz8VdNtl6EPIYi7DawCLlAA==
# DRDGu4oAGQAAAMclQBc9FBs85UcCARoCCgwK/0wAEAVCHJ2Msw==
# ERBH1YoAJwAAALYlQiVjwFJQuxAeFvP+ShcjTkpBWBEyw3UZg20CH+vtU1QuC9rHn3f8
# EBBUAIsAIwAAAMclQiF2neGTeHgCARoX/0wACQgTA8CoMhUbWBYIABmhxZ2PJjs=
# DRAtWIsAGQAAAMclQBe2FDfuG0ECARoCCgwK/0wAEAVCHJ2Msw==
# CRDLWYsADgAAAKclwwwqXIAmBEm2FDfuG0E=
# BxASW4sACAAAAMclRAa2FDfuG0E=
# EBCn2YsAJAAAALMlAiLfyGSNI8Ab/3UAQgQBgGbAI41kyN/CI41kyN4BtSsAAAAA
# EBBN8IsAJAAAAKklYCLMbJLHuQECAQIYFvH8BCBFYB2HF4mk3Vd1tHOMRCo4AW4Z
# ERCyV40AJwAAAMAlYCU4XoEbPG0CAQIb/3UAAhhhsTqHAUVjT4+dNFcYo9QXAsXZrySO
# EBB4yY0AIwAAAMclQiF2
#
# PASSTRHOUGH
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
#
# TI Packet Sniffer ver.1.10.0
